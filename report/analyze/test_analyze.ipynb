# %% [markdown]
# # Testing Data Analyze

# %%
import pandas as pd

# %%
def print_columns(data):
    print(data.columns)

def print_info(data):
    print(data.info())

def print_analyze(data):
    for col in data.columns:
        if col != "student_id":
            items = (data[col].dropna().astype(str).value_counts().sort_index())
            print(f"Column: {col}")
            print("─" * 40)
            for value, count in items.items():
                print(f'==>  "{value}" - {count} count')
            print("\n")

# %%
testing_data = pd.read_csv('../../data/test.csv')

# %%
print_columns(testing_data)
# Out:
# Index(['student_id', 'school', 'gender', 'age', 'address_type', 'family_size',
#        'parent_status', 'mother_education', 'father_education', 'mother_job',
#        'father_job', 'school_reason', 'guardian', 'travel_time', 'study_time',
#        'class_failures', 'school_support', 'family_support',
#        'extra_paid_classes', 'activities', 'nursery_school',
#        'higher_education', 'internet_access', 'romantic_relationship',
#        'family_relationship', 'free_time', 'social', 'weekday_alcohol',
#        'weekend_alcohol', 'health', 'absences', 'grade_1', 'grade_2',
#        'final_grade'],
#       dtype='str')

# %%
print_info(testing_data)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 34 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   student_id             649 non-null    int64
#  1   school                 649 non-null    str
#  2   gender                 649 non-null    str
#  3   age                    649 non-null    int64
#  4   address_type           649 non-null    str
#  5   family_size            649 non-null    str
#  6   parent_status          649 non-null    str
#  7   mother_education       649 non-null    str
#  8   father_education       649 non-null    str
#  9   mother_job             649 non-null    str
#  10  father_job             649 non-null    str
#  11  school_reason          649 non-null    str
#  12  guardian               649 non-null    str
#  13  travel_time            649 non-null    str
#  14  study_time             649 non-null    str
#  15  class_failures         649 non-null    int64
#  16  school_support         649 non-null    str
#  17  family_support         649 non-null    str
#  18  extra_paid_classes     649 non-null    str
#  19  activities             649 non-null    str
#  20  nursery_school         649 non-null    str
#  21  higher_education       649 non-null    str
#  22  internet_access        649 non-null    str
#  23  romantic_relationship  649 non-null    str
#  24  family_relationship    649 non-null    int64
#  25  free_time              649 non-null    int64
#  26  social                 649 non-null    int64
#  27  weekday_alcohol        649 non-null    int64
#  28  weekend_alcohol        649 non-null    int64
#  29  health                 649 non-null    int64
#  30  absences               649 non-null    int64
#  31  grade_1                649 non-null    int64
#  32  grade_2                649 non-null    int64
#  33  final_grade            649 non-null    int64
# dtypes: int64(13), str(21)
# memory usage: 172.5 KB
# None

# %%
print_analyze(testing_data)
# Out:
# Column: school
# ────────────────────────────────────────
# ==>  "GP" - 423 count
# ==>  "MS" - 226 count
#
#
# Column: gender
# ────────────────────────────────────────
# ==>  "F" - 383 count
# ==>  "M" - 266 count
#
#
# Column: age
# ────────────────────────────────────────
# ==>  "15" - 112 count
# ==>  "16" - 177 count
# ==>  "17" - 179 count
# ==>  "18" - 140 count
# ==>  "19" - 32 count
# ==>  "20" - 6 count
# ==>  "21" - 2 count
# ==>  "22" - 1 count
#
#
# Column: address_type
# ────────────────────────────────────────
# ==>  "Rural" - 197 count
# ==>  "Urban" - 452 count
#
#
# Column: family_size
# ────────────────────────────────────────
# ==>  "Greater than 3" - 457 count
# ==>  "Less than or equal to 3" - 192 count
#
#
# Column: parent_status
# ────────────────────────────────────────
# ==>  "Apart" - 80 count
# ==>  "Living together" - 569 count
#
#
# Column: mother_education
# ────────────────────────────────────────
# ==>  "5th to 9th grade" - 186 count
# ==>  "higher education" - 175 count
# ==>  "none" - 6 count
# ==>  "primary education (4th grade)" - 143 count
# ==>  "secondary education" - 139 count
#
#
# Column: father_education
# ────────────────────────────────────────
# ==>  "5th to 9th grade" - 209 count
# ==>  "higher education" - 128 count
# ==>  "none" - 7 count
# ==>  "primary education (4th grade)" - 174 count
# ==>  "secondary education" - 131 count
#
#
# Column: mother_job
# ────────────────────────────────────────
# ==>  "at_home" - 135 count
# ==>  "health" - 48 count
# ==>  "other" - 258 count
# ==>  "services" - 136 count
# ==>  "teacher" - 72 count
#
#
# Column: father_job
# ────────────────────────────────────────
# ==>  "at_home" - 42 count
# ==>  "health" - 23 count
# ==>  "other" - 367 count
# ==>  "services" - 181 count
# ==>  "teacher" - 36 count
#
#
# Column: school_reason
# ────────────────────────────────────────
# ==>  "course" - 285 count
# ==>  "home" - 149 count
# ==>  "other" - 72 count
# ==>  "reputation" - 143 count
#
#
# Column: guardian
# ────────────────────────────────────────
# ==>  "father" - 153 count
# ==>  "mother" - 455 count
# ==>  "other" - 41 count
#
#
# Column: travel_time
# ────────────────────────────────────────
# ==>  "15 to 30 min." - 213 count
# ==>  "30 min. to 1 hour" - 54 count
# ==>  "<15 min." - 366 count
# ==>  ">1 hour" - 16 count
#
#
# Column: study_time
# ────────────────────────────────────────
# ==>  "2 to 5 hours" - 305 count
# ==>  "5 to 10 hours" - 97 count
# ==>  "<2 hours" - 212 count
# ==>  ">10 hours" - 35 count
#
#
# Column: class_failures
# ────────────────────────────────────────
# ==>  "0" - 549 count
# ==>  "1" - 70 count
# ==>  "2" - 16 count
# ==>  "3" - 14 count
#
#
# Column: school_support
# ────────────────────────────────────────
# ==>  "no" - 581 count
# ==>  "yes" - 68 count
#
#
# Column: family_support
# ────────────────────────────────────────
# ==>  "no" - 251 count
# ==>  "yes" - 398 count
#
#
# Column: extra_paid_classes
# ────────────────────────────────────────
# ==>  "no" - 610 count
# ==>  "yes" - 39 count
#
#
# Column: activities
# ────────────────────────────────────────
# ==>  "no" - 334 count
# ==>  "yes" - 315 count
#
#
# Column: nursery_school
# ────────────────────────────────────────
# ==>  "no" - 128 count
# ==>  "yes" - 521 count
#
#
# Column: higher_education
# ────────────────────────────────────────
# ==>  "no" - 69 count
# ==>  "yes" - 580 count
#
#
# Column: internet_access
# ────────────────────────────────────────
# ==>  "no" - 151 count
# ==>  "yes" - 498 count
#
#
# Column: romantic_relationship
# ────────────────────────────────────────
# ==>  "no" - 410 count
# ==>  "yes" - 239 count
#
#
# Column: family_relationship
# ────────────────────────────────────────
# ==>  "1" - 22 count
# ==>  "2" - 29 count
# ==>  "3" - 101 count
# ==>  "4" - 317 count
# ==>  "5" - 180 count
#
#
# Column: free_time
# ────────────────────────────────────────
# ==>  "1" - 45 count
# ==>  "2" - 107 count
# ==>  "3" - 251 count
# ==>  "4" - 178 count
# ==>  "5" - 68 count
#
#
# Column: social
# ────────────────────────────────────────
# ==>  "1" - 48 count
# ==>  "2" - 145 count
# ==>  "3" - 205 count
# ==>  "4" - 141 count
# ==>  "5" - 110 count
#
#
# Column: weekday_alcohol
# ────────────────────────────────────────
# ==>  "1" - 451 count
# ==>  "2" - 121 count
# ==>  "3" - 43 count
# ==>  "4" - 17 count
# ==>  "5" - 17 count
#
#
# Column: weekend_alcohol
# ────────────────────────────────────────
# ==>  "1" - 247 count
# ==>  "2" - 150 count
# ==>  "3" - 120 count
# ==>  "4" - 87 count
# ==>  "5" - 45 count
#
#
# Column: health
# ────────────────────────────────────────
# ==>  "1" - 90 count
# ==>  "2" - 78 count
# ==>  "3" - 124 count
# ==>  "4" - 108 count
# ==>  "5" - 249 count
#
#
# Column: absences
# ────────────────────────────────────────
# ==>  "0" - 244 count
# ==>  "1" - 12 count
# ==>  "10" - 21 count
# ==>  "11" - 5 count
# ==>  "12" - 12 count
# ==>  "13" - 1 count
# ==>  "14" - 8 count
# ==>  "15" - 2 count
# ==>  "16" - 10 count
# ==>  "18" - 3 count
# ==>  "2" - 110 count
# ==>  "21" - 2 count
# ==>  "22" - 2 count
# ==>  "24" - 1 count
# ==>  "26" - 1 count
# ==>  "3" - 7 count
# ==>  "30" - 1 count
# ==>  "32" - 1 count
# ==>  "4" - 93 count
# ==>  "5" - 12 count
# ==>  "6" - 49 count
# ==>  "7" - 3 count
# ==>  "8" - 42 count
# ==>  "9" - 7 count
#
#
# Column: grade_1
# ────────────────────────────────────────
# ==>  "0" - 1 count
# ==>  "10" - 95 count
# ==>  "11" - 91 count
# ==>  "12" - 82 count
# ==>  "13" - 72 count
# ==>  "14" - 71 count
# ==>  "15" - 35 count
# ==>  "16" - 22 count
# ==>  "17" - 16 count
# ==>  "18" - 7 count
# ==>  "19" - 1 count
# ==>  "4" - 2 count
# ==>  "5" - 5 count
# ==>  "6" - 9 count
# ==>  "7" - 33 count
# ==>  "8" - 42 count
# ==>  "9" - 65 count
#
#
# Column: grade_2
# ────────────────────────────────────────
# ==>  "0" - 7 count
# ==>  "10" - 83 count
# ==>  "11" - 103 count
# ==>  "12" - 86 count
# ==>  "13" - 80 count
# ==>  "14" - 54 count
# ==>  "15" - 38 count
# ==>  "16" - 25 count
# ==>  "17" - 20 count
# ==>  "18" - 14 count
# ==>  "19" - 1 count
# ==>  "5" - 3 count
# ==>  "6" - 7 count
# ==>  "7" - 16 count
# ==>  "8" - 40 count
# ==>  "9" - 72 count
#
#
# Column: final_grade
# ────────────────────────────────────────
# ==>  "0" - 15 count
# ==>  "1" - 1 count
# ==>  "10" - 97 count
# ==>  "11" - 104 count
# ==>  "12" - 72 count
# ==>  "13" - 82 count
# ==>  "14" - 63 count
# ==>  "15" - 49 count
# ==>  "16" - 36 count
# ==>  "17" - 29 count
# ==>  "18" - 15 count
# ==>  "19" - 2 count
# ==>  "5" - 1 count
# ==>  "6" - 3 count
# ==>  "7" - 10 count
# ==>  "8" - 35 count
# ==>  "9" - 35 count
